# %% [markdown]
# ### Data gathering, accessing and cleaning
# > Preparing you data for analysis

# %%
import pandas as pd

# %% [markdown]
# ### Data gathering

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Data Accessment
# > * *Visual accessment* - *look through data to find issues*
# > * *Programatic accessment* - Writing codes to access data
#
# - Change column names to lower case
# - Make Pclass column more descriptive
# - Split the name column into last name and other names
# - Change Age column from float to an integer
# - Delete the Ticket and Carbin columns

# %%
# Check for duplicates in data 
duplicates = titanic.duplicated().sum()
print(f"Number of duplicates:{duplicates}")
# Out:
# Number of duplicates:0

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# Info and Describe functions are for programatic accessment of data

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe() # Shows summary statistics of all numerical columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Check the passenger whose age is 0.42

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# >Changing column names to lower case

# %%
titanic.columns = titanic.columns.str.lower()

# %%
titanic
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
titanic.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
titanic.tail(2)
# Out:
#      passengerid  survived  pclass                   name   sex   age  sibsp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      parch  ticket   fare cabin embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# Change pclass to passenger class

# %%
titanic.rename(columns={"pclass":"passenger_class"}, inplace=True)

# %%
titanic
# Out:
#      passengerid  survived  passenger_class  \
# 0              1         0                3
# 1              2         1                1
# 2              3         1                3
# 3              4         1                1
# 4              5         0                3
# ..           ...       ...              ...
# 886          887         0                2
# 887          888         1                1
# 888          889         0                3
# 889          890         1                1
# 890          891         0                3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.rename(columns={"passengerid":"passenger_id"}, inplace=True)

# %%
titanic
# Out:
#      passenger_id  survived  passenger_class  \
# 0               1         0                3
# 1               2         1                1
# 2               3         1                3
# 3               4         1                1
# 4               5         0                3
# ..            ...       ...              ...
# 886           887         0                2
# 887           888         1                1
# 888           889         0                3
# 889           890         1                1
# 890           891         0                3
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# Make Pclass column more descriptive

# %%
 class_mapping = {1:"first class", 2:"second class", 3: "third class"}

# %%
titanic["passenger_class"]= titanic["passenger_class"].map(class_mapping)

# %%
titanic
# Out:
#      passenger_id  survived passenger_class  \
# 0               1         0     third class
# 1               2         1     first class
# 2               3         1     third class
# 3               4         1     first class
# 4               5         0     third class
# ..            ...       ...             ...
# 886           887         0    second class
# 887           888         1     first class
# 888           889         0     third class
# 889           890         1     first class
# 890           891         0     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# Split the name column into last name and other names

# %%
titanic["last_name"] = titanic["name"].str.split(', ', expand=True)[0]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class  \
# 0               1         0     third class
# 1               2         1     first class
# 2               3         1     third class
# 3               4         1     first class
# 4               5         0     third class
# ..            ...       ...             ...
# 886           887         0    second class
# 887           888         1     first class
# 888           889         0     third class
# 889           890         1     first class
# 890           891         0     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic["other_names"] = titanic["name"].str.split(', ', expand=True)[1]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class  \
# 0               1         0     third class
# 1               2         1     first class
# 2               3         1     third class
# 3               4         1     first class
# 4               5         0     third class
# ..            ...       ...             ...
# 886           887         0    second class
# 887           888         1     first class
# 888           889         0     third class
# 889           890         1     first class
# 890           891         0     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic["other_names"] = titanic["other_names"].str.split('. ', expand=True)[1]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class  \
# 0               1         0     third class
# 1               2         1     first class
# 2               3         1     third class
# 3               4         1     first class
# 4               5         0     third class
# ..            ...       ...             ...
# 886           887         0    second class
# 887           888         1     first class
# 888           889         0     third class
# 889           890         1     first class
# 890           891         0     third class
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
del titanic["name"]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1         0     third class    male  22.0      1      0
# 1               2         1     first class  female  38.0      1      0
# 2               3         1     third class  female  26.0      0      0
# 3               4         1     first class  female  35.0      1      0
# 4               5         0     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887         0    second class    male  27.0      0      0
# 887           888         1     first class  female  19.0      0      0
# 888           889         0     third class  female   NaN      1      2
# 889           890         1     first class    male  26.0      0      0
# 890           891         0     third class    male  32.0      0      0
#
#                ticket     fare cabin embarked  last_name other_names
# ...

# %%
del titanic["other_names"]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1         0     third class    male  22.0      1      0
# 1               2         1     first class  female  38.0      1      0
# 2               3         1     third class  female  26.0      0      0
# 3               4         1     first class  female  35.0      1      0
# 4               5         0     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887         0    second class    male  27.0      0      0
# 887           888         1     first class  female  19.0      0      0
# 888           889         0     third class  female   NaN      1      2
# 889           890         1     first class    male  26.0      0      0
# 890           891         0     third class    male  32.0      0      0
#
#                ticket     fare cabin embarked  last_name
# ...

# %%
titanic.pop("ticket")
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: ticket, Length: 891, dtype: object

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1         0     third class    male  22.0      1      0
# 1               2         1     first class  female  38.0      1      0
# 2               3         1     third class  female  26.0      0      0
# 3               4         1     first class  female  35.0      1      0
# 4               5         0     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887         0    second class    male  27.0      0      0
# 887           888         1     first class  female  19.0      0      0
# 888           889         0     third class  female   NaN      1      2
# 889           890         1     first class    male  26.0      0      0
# 890           891         0     third class    male  32.0      0      0
#
#         fare cabin embarked  last_name
# 0     7.2500   NaN        S     Braund
# ...

# %%
titanic.drop(columns = "cabin")
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1         0     third class    male  22.0      1      0
# 1               2         1     first class  female  38.0      1      0
# 2               3         1     third class  female  26.0      0      0
# 3               4         1     first class  female  35.0      1      0
# 4               5         0     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887         0    second class    male  27.0      0      0
# 887           888         1     first class  female  19.0      0      0
# 888           889         0     third class  female   NaN      1      2
# 889           890         1     first class    male  26.0      0      0
# 890           891         0     third class    male  32.0      0      0
#
#         fare embarked  last_name
# 0     7.2500        S     Braund
# 1    71.2833        C    Cumings
# ...

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1         0     third class    male  22.0      1      0
# 1               2         1     first class  female  38.0      1      0
# 2               3         1     third class  female  26.0      0      0
# 3               4         1     first class  female  35.0      1      0
# 4               5         0     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887         0    second class    male  27.0      0      0
# 887           888         1     first class  female  19.0      0      0
# 888           889         0     third class  female   NaN      1      2
# 889           890         1     first class    male  26.0      0      0
# 890           891         0     third class    male  32.0      0      0
#
#         fare cabin embarked  last_name
# 0     7.2500   NaN        S     Braund
# ...

# %%
titanic["survived"] = titanic["survived"].replace(0, "Died")

# %%
titanic
# Out:
#      passenger_id survived passenger_class     sex   age  sibsp  parch  \
# 0               1     Died     third class    male  22.0      1      0
# 1               2        1     first class  female  38.0      1      0
# 2               3        1     third class  female  26.0      0      0
# 3               4        1     first class  female  35.0      1      0
# 4               5     Died     third class    male  35.0      0      0
# ..            ...      ...             ...     ...   ...    ...    ...
# 886           887     Died    second class    male  27.0      0      0
# 887           888        1     first class  female  19.0      0      0
# 888           889     Died     third class  female   NaN      1      2
# 889           890        1     first class    male  26.0      0      0
# 890           891     Died     third class    male  32.0      0      0
#
#         fare cabin embarked  last_name
# 0     7.2500   NaN        S     Braund
# ...

# %%
titanic["survived"] = titanic["survived"].replace(1, "Survived")

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1      Died     third class    male  22.0      1      0
# 1               2  Survived     first class  female  38.0      1      0
# 2               3  Survived     third class  female  26.0      0      0
# 3               4  Survived     first class  female  35.0      1      0
# 4               5      Died     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887      Died    second class    male  27.0      0      0
# 887           888  Survived     first class  female  19.0      0      0
# 888           889      Died     third class  female   NaN      1      2
# 889           890  Survived     first class    male  26.0      0      0
# 890           891      Died     third class    male  32.0      0      0
#
#         fare cabin embarked  last_name
# 0     7.2500   NaN        S     Braund
# ...

# %% [markdown]
# Conbine **`sibsp`** which is sibling and spouse, **`parch`** which is parents and children plus the individual to create a new cloumn called **`family_size`**

# %%
titanic["family_size"]= titanic["sibsp"] + titanic["parch"] + 1

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  sibsp  parch  \
# 0               1      Died     third class    male  22.0      1      0
# 1               2  Survived     first class  female  38.0      1      0
# 2               3  Survived     third class  female  26.0      0      0
# 3               4  Survived     first class  female  35.0      1      0
# 4               5      Died     third class    male  35.0      0      0
# ..            ...       ...             ...     ...   ...    ...    ...
# 886           887      Died    second class    male  27.0      0      0
# 887           888  Survived     first class  female  19.0      0      0
# 888           889      Died     third class  female   NaN      1      2
# 889           890  Survived     first class    male  26.0      0      0
# 890           891      Died     third class    male  32.0      0      0
#
#         fare cabin embarked  last_name  family_size
# ...

# %%
del titanic["sibsp"]

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  parch     fare  \
# 0               1      Died     third class    male  22.0      0   7.2500
# 1               2  Survived     first class  female  38.0      0  71.2833
# 2               3  Survived     third class  female  26.0      0   7.9250
# 3               4  Survived     first class  female  35.0      0  53.1000
# 4               5      Died     third class    male  35.0      0   8.0500
# ..            ...       ...             ...     ...   ...    ...      ...
# 886           887      Died    second class    male  27.0      0  13.0000
# 887           888  Survived     first class  female  19.0      0  30.0000
# 888           889      Died     third class  female   NaN      2  23.4500
# 889           890  Survived     first class    male  26.0      0  30.0000
# 890           891      Died     third class    male  32.0      0   7.7500
#
#     cabin embarked  last_name  family_size
# ...

# %%
titanic.drop(columns = "parch")
# Out:
#      passenger_id  survived passenger_class     sex   age     fare cabin  \
# 0               1      Died     third class    male  22.0   7.2500   NaN
# 1               2  Survived     first class  female  38.0  71.2833   C85
# 2               3  Survived     third class  female  26.0   7.9250   NaN
# 3               4  Survived     first class  female  35.0  53.1000  C123
# 4               5      Died     third class    male  35.0   8.0500   NaN
# ..            ...       ...             ...     ...   ...      ...   ...
# 886           887      Died    second class    male  27.0  13.0000   NaN
# 887           888  Survived     first class  female  19.0  30.0000   B42
# 888           889      Died     third class  female   NaN  23.4500   NaN
# 889           890  Survived     first class    male  26.0  30.0000  C148
# 890           891      Died     third class    male  32.0   7.7500   NaN
#
#     embarked  last_name  family_size
# 0          S     Braund            2
# ...

# %%
titanic.drop(columns = "cabin")
# Out:
#      passenger_id  survived passenger_class     sex   age  parch     fare  \
# 0               1      Died     third class    male  22.0      0   7.2500
# 1               2  Survived     first class  female  38.0      0  71.2833
# 2               3  Survived     third class  female  26.0      0   7.9250
# 3               4  Survived     first class  female  35.0      0  53.1000
# 4               5      Died     third class    male  35.0      0   8.0500
# ..            ...       ...             ...     ...   ...    ...      ...
# 886           887      Died    second class    male  27.0      0  13.0000
# 887           888  Survived     first class  female  19.0      0  30.0000
# 888           889      Died     third class  female   NaN      2  23.4500
# 889           890  Survived     first class    male  26.0      0  30.0000
# 890           891      Died     third class    male  32.0      0   7.7500
#
#     embarked  last_name  family_size
# 0          S     Braund            2
# ...

# %% [markdown]
# Make point of embarkation (embarked) more descriptive **` S for Southampton`**, **`C for Cherbourg`** and **`Q for Queensland`**

# %%
titanic["embarked"]= titanic["embarked"].replace("S", "Southampton")

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  parch     fare  \
# 0               1      Died     third class    male  22.0      0   7.2500
# 1               2  Survived     first class  female  38.0      0  71.2833
# 2               3  Survived     third class  female  26.0      0   7.9250
# 3               4  Survived     first class  female  35.0      0  53.1000
# 4               5      Died     third class    male  35.0      0   8.0500
# ..            ...       ...             ...     ...   ...    ...      ...
# 886           887      Died    second class    male  27.0      0  13.0000
# 887           888  Survived     first class  female  19.0      0  30.0000
# 888           889      Died     third class  female   NaN      2  23.4500
# 889           890  Survived     first class    male  26.0      0  30.0000
# 890           891      Died     third class    male  32.0      0   7.7500
#
#     cabin     embarked  last_name  family_size
# ...

# %%
titanic["embarked"] = titanic["embarked"].replace({"C":"Cherbourg", "Q":"Queensland"})

# %%
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  parch     fare  \
# 0               1      Died     third class    male  22.0      0   7.2500
# 1               2  Survived     first class  female  38.0      0  71.2833
# 2               3  Survived     third class  female  26.0      0   7.9250
# 3               4  Survived     first class  female  35.0      0  53.1000
# 4               5      Died     third class    male  35.0      0   8.0500
# ..            ...       ...             ...     ...   ...    ...      ...
# 886           887      Died    second class    male  27.0      0  13.0000
# 887           888  Survived     first class  female  19.0      0  30.0000
# 888           889      Died     third class  female   NaN      2  23.4500
# 889           890  Survived     first class    male  26.0      0  30.0000
# 890           891      Died     third class    male  32.0      0   7.7500
#
#     cabin     embarked  last_name  family_size
# ...

# %%
# Cabin column has been deleted
titanic
# Out:
#      passenger_id  survived passenger_class     sex   age  parch     fare  \
# 0               1      Died     third class    male  22.0      0   7.2500
# 1               2  Survived     first class  female  38.0      0  71.2833
# 2               3  Survived     third class  female  26.0      0   7.9250
# 3               4  Survived     first class  female  35.0      0  53.1000
# 4               5      Died     third class    male  35.0      0   8.0500
# ..            ...       ...             ...     ...   ...    ...      ...
# 886           887      Died    second class    male  27.0      0  13.0000
# 887           888  Survived     first class  female  19.0      0  30.0000
# 888           889      Died     third class  female   NaN      2  23.4500
# 889           890  Survived     first class    male  26.0      0  30.0000
# 890           891      Died     third class    male  32.0      0   7.7500
#
#         embarked  last_name  family_size
# ...

# %% [markdown]
# ## Descriptive Statistics
#
# >Descriptive statistics will help us to explore simplified interpretation of our data

# %% [markdown]
# Explore the total number of passengers onboard the titanic from the various embarkation centers ( Southanpton, Cherbourg and Queensland

# %%
embarkation_counts = titanic["embarked"].value_counts()

# %%
embarkation_counts
# Out:
# Southampton    644
# Cherbourg      168
# Queensland      77
# Name: embarked, dtype: int64

# %% [markdown]
# ### Create a bar chart to show the above visually and also a piechart to show each contribution to the whole

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
titanic["embarked"].value_counts().plot(kind="bar")
plt.title("Passenger by Embarkation Center")
plt.xlabel("Embarkation Center")
plt.ylabel("Number of Passengers")
plt.show()

# %%
plt.figure(figsize=(8,6))
titanic["embarked"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Passenger by Embarkation Center")
plt.show()

# %% [markdown]
# ### Explore embarkation by gender and by passenger class  (**`Cross tabulation`**)

# %% [markdown]
# ### **`Embarkation by Gender`**

# %%
gender_embarkation = pd.crosstab(titanic["sex"],titanic["embarked"])

# %%
gender_embarkation
# Out:
# embarked  Cherbourg  Queensland  Southampton
# sex
# female           73          36          203
# male             95          41          441

# %% [markdown]
# ### **`Embarkation by passenger class`**

# %%
pclass_embarkation = pd.crosstab(titanic["passenger_class"], titanic["embarked"])

# %%
pclass_embarkation
# Out:
# embarked         Cherbourg  Queensland  Southampton
# passenger_class
# first class             85           2          127
# second class            17           3          164
# third class             66          72          353

# %% [markdown]
# ### **`Sex by Passenger class`**

# %%
sex_pclass = pd.crosstab(titanic["sex"], titanic["passenger_class"])

# %%
sex_pclass
# Out:
# passenger_class  first class  second class  third class
# sex
# female                    94            76          144
# male                     122           108          347

# %% [markdown]
# ### **`Sex by fate (Survival status)`**

# %%
sex_survival = pd.crosstab(titanic["sex"], titanic["survived"])

# %%
sex_survival
# Out:
# survived  Died  Survived
# sex
# female      81       233
# male       468       109

# %% [markdown]
# ### Explore the minimum fare, the average fare and the maximum for paid by passengers

# %%
min_fare = titanic["fare"].min()
avg_fare = titanic["fare"].mean()
max_fare = titanic["fare"].max()

print("The minimum fare paid by a passenger is: €{}".format(min_fare))
print("The average fare paid by a passenger is: €{}".format(avg_fare))
print("The maximum fare paid by a passenger is: €{}".format(max_fare))
# Out:
# The minimum fare paid by a passenger is: €0.0
# The average fare paid by a passenger is: €32.204207968574636
# The maximum fare paid by a passenger is: €512.3292
